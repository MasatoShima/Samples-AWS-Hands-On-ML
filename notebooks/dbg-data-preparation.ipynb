# %% [markdown]
# # Stock Price Prediction Using Deutsche Börse Dataset on SageMaker DeepAR
#
#
# ## Overview
# In this project we use Deutsche Börse Public Dataset consisting of trade data aggregated to one minute intervals from the Xetra trading systems
#
# We obtain the data from public S3 bucket, hosted by Deutsche Börse under AWS Open Data Registry, aggregate the data within a given period, and prepare training, test and validation sets.
# We then upload the prepared dat set to our own S3 bucket. This data location is then used with SageMaker provided DeepAR algorithm, to predict future movement of stock prices.
#
# Following diagrams provides an high level overview of the project architecture:
# ![ML Architecture](../images/architecture.png)

# %%
import os
import io
import datetime

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import autocorrelation_plot
from pandas.plotting import scatter_matrix
from jinja2 import Environment, FileSystemLoader

import boto3
import sagemaker

# %matplotlib inline

# Define IAM role and session
role = sagemaker.get_execution_role()
session = sagemaker.Session()

s3_data_key = 'dbg-stockdata/source'
s3_bucket = session.default_bucket()
processed_filename = 'dbg_processed'

source_bucket = "s3://deutsche-boerse-xetra-pds"

# %% [markdown]
# ## 1. Obtaining Data
#
# Since the DBG dataset is partitioned into separate folders by date, we generate a series of scripts to download the data files, in parallel.
#
# DBG dataset contains trading data beginning June-17, 2017. However we chose to download last 6 months of data, so that the processing time is manageable within the scope of this workshop session.

# %%
start_date = datetime.datetime.strptime('2018-04-01','%Y-%m-%d')
start_date_str = start_date.strftime('%Y-%m-%d')

end_date = datetime.datetime.strptime('2018-10-31','%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')


print(f"Download date range: {start_date_str} - {end_date_str}")
# Out:
# Download date range: 2018-04-01 - 2018-10-31

# %% [markdown]
# We store all files in a local folder, prior to pre-processing the data. <br>
# After processing, we store the processed data set in another folder, which we'll then upload to an our SageMaker S3 bucket.

# %%
download_folder = '../data/download'
processed_folder = '../data/processed'

! mkdir -p {download_folder}
! mkdir -p {processed_folder}

# %% [markdown]
# We then generate the download script in script folder and execute it to have the files downloaded.<br>
# Running bash script makes the download more reliable than running loops from Pythin runtime.

# %%
download_script = download_folder + '/download_files.sh'

dates = list(pd.date_range(start_date_str, end_date_str, freq='D').strftime('%Y-%m-%d'))

values_set = {
    "values_set": [
        {
            "date": date,
            "download_folder": download_folder,
            "source_bucket": source_bucket,
            "success_file": os.path.join(download_folder, date, "success")
        }
        for date in dates
    ]
}

env = Environment(loader=FileSystemLoader("."))

tpl = env.get_template("download_files.j2")

source_code = tpl.render(values_set)

with open(download_script, 'w') as f:
    f.write(source_code)

! chmod +x {download_script}

# %% [markdown]
# After creating the script, we run the script from shell, using Jupyter magic command.
#
# Downloading data should take about half an hour to an hour to complete depending on the dat range chosen.
#
# In order to avoid this process, you can alternative use the last cell in this notebook to obtain the prepared data from an S3 bucket accompanying this workshop, and load directly to your own S3 bucket.

# %%
# %%time
!  {download_script}
# Out:
# Getting DBG dataset for date 2018-04-01
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR02.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR01.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR00.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR04.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR11.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR08.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR13.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR10.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR03.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR07.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR16.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR14.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR06.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR18.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR20.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR15.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR17.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR05.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR19.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR21.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR12.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR22.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR09.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-01/2018-04-01_BINS_XETR23.csv to ../data/download/2018-04-01/2018-04-01_BINS_XETR23.csv
# Getting DBG dataset for date 2018-04-02
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR00.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR08.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR04.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR02.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR06.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR09.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR01.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR07.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR03.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR05.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR14.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR12.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR13.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR10.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR15.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR16.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR11.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR18.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR17.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR19.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR20.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR23.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR21.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-02/2018-04-02_BINS_XETR22.csv to ../data/download/2018-04-02/2018-04-02_BINS_XETR22.csv
# Getting DBG dataset for date 2018-04-03
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR06.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR03.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR05.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR00.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR02.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR04.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR01.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR19.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR20.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR16.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR18.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR17.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR22.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR09.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR08.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR10.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR23.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR21.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR13.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR07.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR12.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR14.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR15.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-03/2018-04-03_BINS_XETR11.csv to ../data/download/2018-04-03/2018-04-03_BINS_XETR11.csv
# Getting DBG dataset for date 2018-04-04
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR01.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR00.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR02.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR06.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR04.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR05.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR03.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR18.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR20.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR19.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR21.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR23.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR22.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR16.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR17.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR07.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR09.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR13.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR08.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR10.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR14.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR12.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR11.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-04/2018-04-04_BINS_XETR15.csv to ../data/download/2018-04-04/2018-04-04_BINS_XETR15.csv
# Getting DBG dataset for date 2018-04-05
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR01.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR06.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR03.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR05.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR02.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR04.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR00.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR16.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR18.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR19.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR20.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR07.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR17.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR10.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR11.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR21.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR13.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR15.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR08.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR14.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR22.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR23.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR12.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-05/2018-04-05_BINS_XETR09.csv to ../data/download/2018-04-05/2018-04-05_BINS_XETR09.csv
# Getting DBG dataset for date 2018-04-06
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR00.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR04.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR02.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR03.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR05.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR01.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR06.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR16.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR17.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR18.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR19.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR20.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR09.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR08.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR21.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR10.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR23.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR11.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR22.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR14.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR12.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR07.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR13.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-06/2018-04-06_BINS_XETR15.csv to ../data/download/2018-04-06/2018-04-06_BINS_XETR15.csv
# Getting DBG dataset for date 2018-04-07
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR00.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR03.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR06.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR08.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR07.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR04.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR02.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR01.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR09.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR05.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR14.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR12.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR17.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR11.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR10.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR15.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR16.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR18.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR19.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR13.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR20.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR21.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR22.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-07/2018-04-07_BINS_XETR23.csv to ../data/download/2018-04-07/2018-04-07_BINS_XETR23.csv
# Getting DBG dataset for date 2018-04-08
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR00.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR07.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR12.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR02.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR06.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR04.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR01.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR11.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR09.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR03.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR10.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR08.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR14.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR17.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR13.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR16.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR20.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR21.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR15.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR23.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR19.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR18.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR05.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-08/2018-04-08_BINS_XETR22.csv to ../data/download/2018-04-08/2018-04-08_BINS_XETR22.csv
# Getting DBG dataset for date 2018-04-09
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR01.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR06.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR05.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR00.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR03.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR02.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR04.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR17.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR16.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR20.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR21.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR18.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR22.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR08.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR09.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR19.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR23.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR11.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR07.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR15.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR12.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR10.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR13.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-09/2018-04-09_BINS_XETR14.csv to ../data/download/2018-04-09/2018-04-09_BINS_XETR14.csv
# Getting DBG dataset for date 2018-04-10
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR01.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR02.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR00.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR04.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR06.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR05.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR03.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR17.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR18.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR22.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR19.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR07.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR08.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR16.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR11.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR21.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR10.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR12.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR09.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR23.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR15.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR20.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR13.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-10/2018-04-10_BINS_XETR14.csv to ../data/download/2018-04-10/2018-04-10_BINS_XETR14.csv
# Getting DBG dataset for date 2018-04-11
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR01.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR04.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR02.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR00.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR03.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR05.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR06.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR16.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR19.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR18.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR22.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR21.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR17.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR20.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR07.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR13.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR23.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR10.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR11.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR09.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR15.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR14.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR08.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-11/2018-04-11_BINS_XETR12.csv to ../data/download/2018-04-11/2018-04-11_BINS_XETR12.csv
# Getting DBG dataset for date 2018-04-12
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR00.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR01.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR03.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR02.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR05.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR06.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR04.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR17.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR19.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR18.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR22.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR16.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR20.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR08.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR07.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR09.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR11.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR21.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR23.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR10.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR12.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR13.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR14.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-12/2018-04-12_BINS_XETR15.csv to ../data/download/2018-04-12/2018-04-12_BINS_XETR15.csv
# Getting DBG dataset for date 2018-04-13
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR01.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR02.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR00.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR05.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR06.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR03.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR17.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR04.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR19.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR21.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR20.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR22.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR23.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR18.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR16.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR12.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR07.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR09.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR10.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR08.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR11.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR13.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR15.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-13/2018-04-13_BINS_XETR14.csv to ../data/download/2018-04-13/2018-04-13_BINS_XETR14.csv
# Getting DBG dataset for date 2018-04-14
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR01.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR03.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR10.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR09.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR07.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR08.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR02.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR06.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR04.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR05.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR11.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR16.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR14.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR17.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR13.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR18.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR15.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR12.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR23.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR22.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR19.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR21.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR20.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-14/2018-04-14_BINS_XETR00.csv to ../data/download/2018-04-14/2018-04-14_BINS_XETR00.csv
# Getting DBG dataset for date 2018-04-15
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR01.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR10.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR02.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR00.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR05.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR09.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR06.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR04.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-04-15/2018-04-15_BINS_XETR11.csv to ../data/download/2018-04-15/2018-04-15_BINS_XETR11.csv
# ...
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR05.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR03.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR13.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR06.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR00.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR10.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR18.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR09.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR12.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR20.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR15.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR14.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR19.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR11.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR21.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR17.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR16.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR23.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR22.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR22.csv
# Getting DBG dataset for date 2018-10-28
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR01.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR02.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR04.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR00.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR09.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR03.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR08.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR06.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR05.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR11.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR10.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR07.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR12.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR13.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR16.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR15.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR14.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR21.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR17.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR19.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR18.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR23.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR20.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR22.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR22.csv
# Getting DBG dataset for date 2018-10-29
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR01.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR00.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR02.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR05.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR07.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR06.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR03.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR04.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR17.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR18.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR20.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR21.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR12.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR08.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR19.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR10.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR11.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR14.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR22.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR13.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR23.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR09.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR15.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR16.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR16.csv
# Getting DBG dataset for date 2018-10-30
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR01.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR02.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR00.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR04.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR05.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR06.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR07.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR03.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR19.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR17.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR18.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR21.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR22.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR09.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR10.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR23.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR11.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR12.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR20.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR15.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR13.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR08.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR16.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR14.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR14.csv
# Getting DBG dataset for date 2018-10-31
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR06.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR02.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR05.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR03.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR00.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR04.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR07.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR01.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR18.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR17.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR20.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR19.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR09.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR22.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR10.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR12.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR08.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR23.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR16.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR21.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR11.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR13.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR15.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR14.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR14.csv
# CPU times: user 28.6 s, sys: 7.15 s, total: 35.7 s
# Wall time: 18min 4s

# %% [markdown]
# ## 2. Data Preparation
#
# To prepare the data, we collect day wise tading data from separate files, filter out any data falling out of trading window, and not pertaining to common stock trading.
#
# ### 2.1. Load Data
# As first step we load all csv files in to a single data frame.
#
# Data loading should take about 1-2 hours to complete depending on the instance type you have chosen for your notebook instance.

# %%
# %%time
def convert_datetime(df):
    try: 
        df["CalcTime"] = pd.to_datetime("1900-01-01 " + df["Time"])
        df["CalcDateTime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

    except:
        pass

    return df


def load_csvs(data_folder):
    df = None
    df_initialized = False
    data_dir = data_folder + '/'
    data_subdirs = list(map(lambda date: data_dir + date, dates))
    total_loaded = 0

    for data_subdir in data_subdirs:
        # data_subdir 配下の csv ファイルの Path を取得
        # ファイルサイズが 2000バイト以下のものは分析用のデータから除外
        # 残った Path を sort
        trading_files = sorted(
            list(
                filter(
                    lambda x:os.path.getsize(x)>2000,
                    [
                        os.path.join(data_subdir, x) 
                        for x in os.listdir(data_subdir) 
                        if x.endswith('.csv')
                    ]
                )
            )
        )

        if len(trading_files) > 0:
            print(f"Loading {len(trading_files)} files from {data_subdir}")

            if df_initialized == False:
                frame = [
                    pd.read_csv(f, engine='python', error_bad_lines=False, warn_bad_lines=False) 
                    for f in trading_files
                ]

                df = convert_datetime(pd.concat(frame, ignore_index = True))
                df_initialized = True

            else:
                dfa = convert_datetime(
                    pd.concat(
                        [
                            pd.read_csv(f, engine='python', error_bad_lines=False) 
                            for f in trading_files
                        ],
                        ignore_index = True
                    )
                )

                dft = [df, dfa]
                df = pd.concat(dft, ignore_index = True)

            total_loaded = total_loaded + len(trading_files)

            print(df.shape)

    print(f"Total of {total_loaded} files loaded")

    return df

unprocessed_df = load_csvs(download_folder)
# Out:
# Loading 9 files from ../data/download/2018-04-03
# (72417, 16)
# Loading 9 files from ../data/download/2018-04-04
# (147912, 16)
# Loading 9 files from ../data/download/2018-04-05
# (215729, 16)
# Loading 10 files from ../data/download/2018-04-06
# (278634, 16)
# Loading 9 files from ../data/download/2018-04-09
# (341127, 16)
# Loading 9 files from ../data/download/2018-04-10
# (404953, 16)
# Loading 9 files from ../data/download/2018-04-11
# (467602, 16)
# Loading 9 files from ../data/download/2018-04-12
# (528697, 16)
# Loading 10 files from ../data/download/2018-04-13
# (589091, 16)
# Loading 9 files from ../data/download/2018-04-16
# (648125, 16)
# Loading 9 files from ../data/download/2018-04-17
# (708129, 16)
# Loading 9 files from ../data/download/2018-04-18
# (770572, 16)
# Loading 9 files from ../data/download/2018-04-19
# (829425, 16)
# Loading 9 files from ../data/download/2018-04-20
# (889980, 16)
# Loading 9 files from ../data/download/2018-04-23
# (950337, 16)
# Loading 6 files from ../data/download/2018-04-24
# (993162, 16)
# Loading 9 files from ../data/download/2018-04-25
# (1061457, 16)
# Loading 9 files from ../data/download/2018-04-26
# (1124857, 16)
# Loading 9 files from ../data/download/2018-04-27
# (1187293, 16)
# Loading 9 files from ../data/download/2018-04-30
# (1246443, 16)
# Loading 9 files from ../data/download/2018-05-02
# (1318597, 16)
# Loading 9 files from ../data/download/2018-05-03
# (1382134, 16)
# Loading 9 files from ../data/download/2018-05-04
# (1443691, 16)
# Loading 9 files from ../data/download/2018-05-07
# (1503264, 16)
# Loading 9 files from ../data/download/2018-05-08
# (1567956, 16)
# Loading 9 files from ../data/download/2018-05-09
# (1633917, 16)
# Loading 9 files from ../data/download/2018-05-10
# (1687002, 16)
# Loading 9 files from ../data/download/2018-05-11
# (1747395, 16)
# Loading 9 files from ../data/download/2018-05-14
# (1810342, 16)
# Loading 9 files from ../data/download/2018-05-15
# (1877616, 16)
# Loading 9 files from ../data/download/2018-05-16
# (1941213, 16)
# Loading 9 files from ../data/download/2018-05-17
# (2003855, 16)
# Loading 9 files from ../data/download/2018-05-18
# (2067222, 16)
# Loading 9 files from ../data/download/2018-05-22
# (2134171, 16)
# Loading 9 files from ../data/download/2018-05-23
# (2202763, 16)
# Loading 9 files from ../data/download/2018-05-24
# (2266344, 16)
# Loading 9 files from ../data/download/2018-05-25
# (2331078, 16)
# Loading 9 files from ../data/download/2018-05-28
# (2385017, 16)
# Loading 9 files from ../data/download/2018-05-29
# (2458607, 16)
# Loading 9 files from ../data/download/2018-05-30
# (2525676, 16)
# Loading 9 files from ../data/download/2018-05-31
# (2589224, 16)
# Loading 9 files from ../data/download/2018-06-01
# (2656215, 16)
# Loading 9 files from ../data/download/2018-06-04
# (2717754, 16)
# Loading 9 files from ../data/download/2018-06-05
# (2782422, 16)
# Loading 9 files from ../data/download/2018-06-06
# (2845905, 16)
# Loading 9 files from ../data/download/2018-06-07
# (2910090, 16)
# Loading 9 files from ../data/download/2018-06-08
# (2973977, 16)
# Loading 9 files from ../data/download/2018-06-11
# (3034845, 16)
# Loading 9 files from ../data/download/2018-06-12
# (3095818, 16)
# Loading 10 files from ../data/download/2018-06-13
# (3155870, 16)
# Loading 10 files from ../data/download/2018-06-14
# (3220763, 16)
# Loading 9 files from ../data/download/2018-06-15
# (3288912, 16)
# Loading 9 files from ../data/download/2018-06-18
# (3350846, 16)
# Loading 9 files from ../data/download/2018-06-19
# (3415222, 16)
# Loading 10 files from ../data/download/2018-06-20
# (3477619, 16)
# Loading 10 files from ../data/download/2018-06-21
# (3543556, 16)
# Loading 9 files from ../data/download/2018-06-22
# (3603148, 16)
# Loading 9 files from ../data/download/2018-06-25
# (3670581, 16)
# Loading 9 files from ../data/download/2018-06-26
# (3733827, 16)
# Loading 10 files from ../data/download/2018-06-27
# (3805100, 16)
# Loading 9 files from ../data/download/2018-06-28
# (3872616, 16)
# Loading 9 files from ../data/download/2018-06-29
# (3938514, 16)
# Loading 9 files from ../data/download/2018-07-02
# (4004735, 16)
# Loading 10 files from ../data/download/2018-07-03
# (4073691, 16)
# Loading 10 files from ../data/download/2018-07-04
# (4134604, 16)
# Loading 10 files from ../data/download/2018-07-05
# (4203903, 16)
# Loading 10 files from ../data/download/2018-07-06
# (4270020, 16)
# Loading 11 files from ../data/download/2018-07-09
# (4334447, 16)
# Loading 11 files from ../data/download/2018-07-10
# (4400687, 16)
# Loading 11 files from ../data/download/2018-07-11
# (4466675, 16)
# Loading 10 files from ../data/download/2018-07-12
# (4531923, 16)
# Loading 9 files from ../data/download/2018-07-16
# (4587614, 16)
# Loading 9 files from ../data/download/2018-07-17
# (4644728, 16)
# Loading 9 files from ../data/download/2018-07-18
# (4705073, 16)
# Loading 9 files from ../data/download/2018-07-19
# (4762559, 16)
# Loading 9 files from ../data/download/2018-07-20
# (4823347, 16)
# Loading 9 files from ../data/download/2018-07-23
# (4878293, 16)
# Loading 9 files from ../data/download/2018-07-24
# (4939923, 16)
# Loading 10 files from ../data/download/2018-07-25
# (5005324, 16)
# Loading 10 files from ../data/download/2018-07-26
# (5076613, 16)
# Loading 10 files from ../data/download/2018-07-27
# (5142868, 16)
# Loading 11 files from ../data/download/2018-07-30
# (5205655, 16)
# Loading 11 files from ../data/download/2018-07-31
# (5271985, 16)
# Loading 10 files from ../data/download/2018-08-01
# (5342631, 16)
# Loading 10 files from ../data/download/2018-08-02
# (5411294, 16)
# Loading 10 files from ../data/download/2018-08-03
# (5474615, 16)
# Loading 10 files from ../data/download/2018-08-06
# (5542608, 16)
# Loading 10 files from ../data/download/2018-08-07
# (5608319, 16)
# Loading 11 files from ../data/download/2018-08-08
# (5675925, 16)
# Loading 10 files from ../data/download/2018-08-09
# (5741895, 16)
# Loading 6 files from ../data/download/2018-08-10
# (5786659, 16)
# Loading 10 files from ../data/download/2018-08-13
# (5853882, 16)
# Loading 10 files from ../data/download/2018-08-14
# (5921366, 16)
# Loading 11 files from ../data/download/2018-08-15
# (5994470, 16)
# Loading 10 files from ../data/download/2018-08-16
# (6060964, 16)
# Loading 10 files from ../data/download/2018-08-17
# (6124657, 16)
# Loading 11 files from ../data/download/2018-08-20
# (6187709, 16)
# Loading 10 files from ../data/download/2018-08-21
# (6249914, 16)
# Loading 10 files from ../data/download/2018-08-22
# (6314403, 16)
# Loading 10 files from ../data/download/2018-08-23
# (6375719, 16)
# Loading 10 files from ../data/download/2018-08-24
# (6436689, 16)
# Loading 10 files from ../data/download/2018-08-27
# (6495867, 16)
# Loading 10 files from ../data/download/2018-08-28
# (6561275, 16)
# Loading 10 files from ../data/download/2018-08-29
# (6625695, 16)
# Loading 10 files from ../data/download/2018-08-30
# (6692544, 16)
# Loading 9 files from ../data/download/2018-08-31
# (6755325, 16)
# Loading 9 files from ../data/download/2018-09-03
# (6815906, 16)
# Loading 9 files from ../data/download/2018-09-04
# (6883305, 16)
# Loading 9 files from ../data/download/2018-09-05
# (6954063, 16)
# Loading 9 files from ../data/download/2018-09-06
# (7023311, 16)
# Loading 10 files from ../data/download/2018-09-07
# (7091334, 16)
# Loading 9 files from ../data/download/2018-09-10
# (7155747, 16)
# Loading 9 files from ../data/download/2018-09-11
# (7219534, 16)
# Loading 10 files from ../data/download/2018-09-12
# (7283928, 16)
# Loading 9 files from ../data/download/2018-09-13
# (7349549, 16)
# Loading 10 files from ../data/download/2018-09-14
# (7411758, 16)
# Loading 9 files from ../data/download/2018-09-17
# (7474938, 16)
# Loading 9 files from ../data/download/2018-09-18
# (7540080, 16)
# Loading 9 files from ../data/download/2018-09-19
# (7603032, 16)
# Loading 9 files from ../data/download/2018-09-20
# (7671539, 16)
# Loading 9 files from ../data/download/2018-09-21
# (7738665, 16)
# Loading 9 files from ../data/download/2018-09-24
# (7801025, 16)
# Loading 9 files from ../data/download/2018-09-25
# (7863869, 16)
# Loading 10 files from ../data/download/2018-09-26
# (7924051, 16)
# Loading 9 files from ../data/download/2018-09-27
# (7986727, 16)
# Loading 9 files from ../data/download/2018-09-28
# (8057409, 16)
# Loading 9 files from ../data/download/2018-10-01
# (8125206, 16)
# Loading 9 files from ../data/download/2018-10-02
# (8192646, 16)
# Loading 9 files from ../data/download/2018-10-04
# (8267834, 16)
# Loading 9 files from ../data/download/2018-10-05
# (8337791, 16)
# Loading 9 files from ../data/download/2018-10-08
# (8410220, 16)
# Loading 10 files from ../data/download/2018-10-09
# (8484005, 16)
# Loading 9 files from ../data/download/2018-10-10
# (8559271, 16)
# Loading 9 files from ../data/download/2018-10-11
# (8654359, 16)
# Loading 10 files from ../data/download/2018-10-12
# (8736806, 16)
# Loading 9 files from ../data/download/2018-10-15
# (8804236, 16)
# Loading 9 files from ../data/download/2018-10-16
# (8877296, 16)
# Loading 9 files from ../data/download/2018-10-17
# (8950273, 16)
# Loading 9 files from ../data/download/2018-10-18
# (9019953, 16)
# Loading 9 files from ../data/download/2018-10-19
# (9093712, 16)
# Loading 10 files from ../data/download/2018-10-22
# (9162320, 16)
# Loading 10 files from ../data/download/2018-10-23
# (9242677, 16)
# Loading 10 files from ../data/download/2018-10-24
# (9317671, 16)
# Loading 10 files from ../data/download/2018-10-25
# (9401422, 16)
# Loading 10 files from ../data/download/2018-10-26
# (9479133, 16)
# Loading 10 files from ../data/download/2018-10-29
# (9554851, 16)
# Loading 10 files from ../data/download/2018-10-30
# (9630277, 16)
# Loading 10 files from ../data/download/2018-10-31
# (9705344, 16)
# Total of 1389 files loaded
# CPU times: user 11min 15s, sys: 2min 34s, total: 13min 50s
# Wall time: 11min 56s

# %%
unprocessed_df.head()
# Out:
#            ISIN Mnemonic              SecurityDesc  SecurityType Currency  \
# 0  AT0000A0E9W5     SANT  S+T AG (Z.REG.MK.Z.)O.N.  Common stock      EUR
# 1  DE000A0DJ6J9      S92      SMA SOLAR TECHNOL.AG  Common stock      EUR
# 2  DE000A0D6554     NDX1            NORDEX SE O.N.  Common stock      EUR
# 3  DE000A0Z2ZZ5     FNTN        FREENET AG NA O.N.  Common stock      EUR
# 4  DE000A1EWWW0      ADS         ADIDAS AG NA O.N.  Common stock      EUR
#
#    SecurityID        Date   Time  StartPrice  MaxPrice  MinPrice  EndPrice  \
# 0     2504159  2018-04-03  07:00       18.03     18.14     18.02     18.14
# 1     2504287  2018-04-03  07:00       45.54     45.54     45.34     45.48
# 2     2504290  2018-04-03  07:00        7.04      7.04      7.04      7.04
# 3     2504438  2018-04-03  07:00       24.74     24.74     24.70     24.70
# 4     2504471  2018-04-03  07:00      194.95    195.00    194.40    194.90
#
#    TradedVolume  NumberOfTrades            CalcTime        CalcDateTime
# 0          1408              15 1900-01-01 07:00:00 2018-04-03 07:00:00
# 1           858              11 1900-01-01 07:00:00 2018-04-03 07:00:00
# 2           125               1 1900-01-01 07:00:00 2018-04-03 07:00:00
# 3          2964               9 1900-01-01 07:00:00 2018-04-03 07:00:00
# 4          2213              36 1900-01-01 07:00:00 2018-04-03 07:00:00

# %% [markdown]
# ### 2.2. Filter records
# Next we filter the records pertaining to common stack with trading volumes greater than zero, and within the regular trading hours.
# Within the scope of this exercise, we focus our attention to top 100 stocks, by trading volume.
#
# This filtering should take about 1-2 minute to complete depending on the instance type you have chosen for your notebook instance.

# %%
# %%time
# Filter common stock between trading hours 08:00 and 20:00
# Exclude auctions (those are with TradeVolume == 0)
#Number of stocks to keep : Top 100, by trading volume
num_stocks=100
time_fmt = "%H:%M"
opening_hours_str = "08:00"
closing_hours_str = "20:00"
opening_hours = datetime.datetime.strptime(opening_hours_str, time_fmt)
closing_hours = datetime.datetime.strptime(closing_hours_str, time_fmt)

common_stocks = unprocessed_df[(unprocessed_df.SecurityType == 'Common stock') & \
                    (unprocessed_df.TradedVolume > 0) & \
                    (unprocessed_df.CalcTime >= opening_hours) & \
                    (unprocessed_df.CalcTime <= closing_hours)]

# Sort the stocks in descending order by trading volume
sort_by_volume = common_stocks[['Mnemonic', 'TradedVolume']].groupby(['Mnemonic']).sum().sort_values(['TradedVolume'], ascending=[0]).head(num_stocks)
stock_symbols = list(sort_by_volume.index.values)
sorted_stocks = common_stocks[common_stocks.Mnemonic.isin(stock_symbols)]
sorted_stocks = sorted_stocks.set_index(['Mnemonic', 'CalcDateTime']).sort_index()
stock_symbols = list(sort_by_volume.index.values)
print(sorted_stocks.shape)

# %% [markdown]
# Check to see how many days' records we imported. If you import all records starting from July-2017, to October-2018, it should contain 326 days' woth of records.

# %%
len(sorted(list(sorted_stocks['Date'].unique())))

# %% [markdown]
# ### 2.3. Select features by minute
#
# Next we build a clean data frame containing minute by minute transaction records with the following data points:
# - Mnemonic (Stock Ticker Symbol)
# - Minimum Price (During the interval)
# - Maximum Prixe (During the interval)
# - Start Price (At star of the interval)
# - End Price (At end of the interval)
# - Trading Volume (During the interval)
# - Number of Trades (During the interval)

# %%
# %%time
#Build minute by minute index for trading hours
non_empty_days = sorted(list(sorted_stocks['Date'].unique()))
def build_index(non_empty_days, from_time, to_time):
    date_ranges = []
    for date in non_empty_days:
        yyyy, mm, dd = date.split('-')
        from_hour, from_min = from_time.split(':')
        to_hour, to_min = to_time.split(':')    
        t1 = datetime.datetime(int(yyyy), int(mm), int(dd), int(from_hour),int(from_min),0)
        t2 = datetime.datetime(int(yyyy), int(mm), int(dd), int(to_hour),int(to_min),0) 
        date_ranges.append(pd.DataFrame({"OrganizedDateTime": pd.date_range(t1, t2, freq='1Min').values}))
    agg = pd.concat(date_ranges, axis=0) 
    agg.index = agg["OrganizedDateTime"]
    return agg

# Prepared data would contain numeric features for all stocks,
# for all days in the interval, for which there were trades (that means excluding weekends and holidays)
# for all minutes from 08:00 until 20:00
# in minutes without trades the prices from the last available minute are carried forward
# trades are filled with zero for such minutes

def basic_stock_features(input_df, mnemonic, time_index):
    stock = input_df.loc[mnemonic].copy()
    stock['HasTrade'] = 1.0    
    stock = stock.reindex(time_index)    
    features = ['MinPrice', 'MaxPrice', 'EndPrice', 'StartPrice']
    for f in features:
        stock[f] = stock[f].fillna(method='ffill')       
    features = ['HasTrade', 'TradedVolume', 'NumberOfTrades']
    for f in features:
        stock[f] = stock[f].fillna(0.0)    
    stock['Mnemonic'] = mnemonic
    selected_features = ['Mnemonic', 'MinPrice', 'MaxPrice', 'StartPrice', 'EndPrice', 'HasTrade', 'TradedVolume', 'NumberOfTrades']
    return stock[selected_features]

datetime_index = build_index(non_empty_days, opening_hours_str, closing_hours_str)["OrganizedDateTime"].values

stocks = []
for stock in stock_symbols:
    stock = basic_stock_features(sorted_stocks, stock, datetime_index)
    stocks.append(stock)

prepared = pd.concat(stocks, axis=0)
prepared.insert(0, 'Id', range(0, 0 + len(prepared)))
prepared = prepared.reset_index().set_index('Id')

# %%
prepared.head()

# %% [markdown]
# ### 2.4. Save processed data
# Finally we save the processed data and upload to our SageMaker S3 Bucket.<br>
# Source data, as downloaded from DBG dataset includes minute by minute details of price movement and trading numbers and volumes for the stocks. However, in practice, we might be interested in time series at various aggregation level, in order to do more effective hourly, daily or weekly predictions.
#
# Therefore we resample the data at various interval levels. First we define a resampling function that is able to resample various metrices for the aggregation levels.<br>
# For example, at a certain interval level, we are interested in:<br>
# - Last record for the End Price
# - First record for the Start Price
# - Minimum of all records for Min Price
# - Maximum of all records for Max Price
# - Total of all records for Number of Trades and Traded Volume

# %%
intervals = ['M', 'W', 'D', 'H']

def resample_data(df, interval = None, mnemonics=None, metrics=None):
    if mnemonics is None:
        mnemonics = list(df.Mnemonic.unique())
    if metrics is None:
        metrics = list(df.columns.values)
    if 'Mnemonic' in metrics:
        metrics.remove('Mnemonic')
    if 'HasTrade' in metrics:
        metrics.remove('HasTrade')        
        
    columns = list(df.columns.values)
    if 'CalcDateTime' not in columns:        
        df["CalcDateTime"] = pd.to_datetime(df["CalcDateTime"])
        
    if interval is None or not isinstance(interval, str) or interval not in intervals:
        raise ValueError('Interval not supported, must be one of : {}'.format(intervals))
        
    resampeled_frames = []         
    for mnemonic in mnemonics:
        print("Resampling {} records for interval - {}".format(mnemonic, interval))
        selected = df[df.Mnemonic == mnemonic].copy()
        selected.index = selected['CalcDateTime']
        selected = selected.sort_index()
        resampled = pd.DataFrame()   
        for metric in metrics:            
            if metric == 'EndPrice':
                resampled[metric] = selected[metric].resample(interval).last()
            elif metric == 'StartPrice':
                resampled[metric] = selected[metric].resample(interval).first()                   
            elif metric == 'MinPrice':
                resampled[metric] = selected[metric].resample(interval).min()                                 
            elif metric == 'MaxPrice':
                resampled[metric] = selected[metric].resample(interval).max()                                  
            elif metric == 'TradedVolume' or metric == "NumberOfTrades" :
                resampled[metric] = selected[metric].resample(interval).sum()                               
            else:
                pass
        resampled_columns = ['Mnemonic']
        for col in list(resampled.columns.values):
            resampled_columns.append(col)
        resampled['Mnemonic'] = mnemonic
        resampled = resampled[resampled_columns]  
        resampled.dropna(inplace = True)
        resampeled_frames.append(resampled)
    resampeleds = pd.concat(resampeled_frames)
    return resampeleds

# %% [markdown]
# Next we do a resampling for the following intervals and upload the file to an appropriate S3 location directly, saving local disk space:
# - Month
# - Week
# - Day
# - Hour
#
# Resampling of the time series data at four different interval levels should take about 10 to 20 minutes to complete, depending on the instance type you have chosen for your notebook instance.
#
# Note that this causes gaps in time series. However SageMaker DeepAR algorithm is designed to work with time series with gaps.

# %%
# %%time
for interval in intervals:
    rescaled_series = resample_data(prepared, interval)
    csv_buffer = io.StringIO()
    rescaled_series.to_csv(csv_buffer)
    s3_resource = boto3.resource('s3')
    s3_resource.Object(s3_bucket, '{}/{}/resampled_stockdata.csv'.format(s3_data_key, interval, interval)).put(Body=csv_buffer.getvalue())

# %% [markdown]
# Having the prepared data saved to an S3 bucket not only allows us to save some space in lcoal machine, but also helps when starting training job using SageMaker.<br>
# Since reading from S3 is optimized for high speed, when you are using an EC2 instance, which is what a SageMaker Notebook instance runs on, it makes sense to just load the data directly from S3, as and when needed.<br><br>
# Also, since SageMaker notebook instances come with only 5GB of Elastic Block Storage (to remain cost efficient), it is advisable to keep the device storage space clean, when not used.<br><br>
# Therefore, we delete the raw data files locally, to conserve storage space on notebook instance.

# %%
#Remove the download folder
# !rm -rf {download_folder}
#Reset the data frames loaded in memory
rescaled_series = None    
prepared = None
unprocessed_df = None

# %% [markdown]
# ### 2.5. Alternatively - Load resampled data for workshop
#
# Since obtaining raw data from source S3 buckets maintained by Deutsche Börse, filtering, resampling and uploading to SageMaker S3 bucket can take upward of two hours, within the time limit of this workshop you could obtain cleaned data as hosted directly from S3 buckets specifically maintained for this workshop.

# %%
import os
import io
import boto3
import sagemaker
import datetime
import pandas as pd
from pandas.tools.plotting import autocorrelation_plot
from pandas.tools.plotting import scatter_matrix
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Define IAM role and session
role = sagemaker.get_execution_role()
session = sagemaker.Session()

s3_data_key = 'dbg-stockdata/source'
s3_bucket = session.default_bucket()
processed_filename = 'dbg_processed'


workshop_bucket = "fsv-309"
intervals = ['M', 'W', 'D', 'H']
datafilename = "resampled_stockdata.csv "

for interval in intervals:
    # !aws s3 cp s3://{workshop_bucket}/{s3_data_key}/{interval}/{datafilename} s3://{s3_bucket}/{s3_data_key}/{interval}/{datafilename}

# %% [markdown]
# ### 2.6. Validate Data Load from S3
#
# Before moving on, we want to validate data by downloading from the location on S3 that we just saved, and run some quick introspection to develop an intuition about the nature of metrices and their possible influence on stock price movement.<br>
# For our preliminary analysis, we choose to load and investigate data with daily interval.

# %%
def load_resampled_from_s3(interval, bucket, s3_data_key):
    s3 = boto3.client('s3')
    obj = s3.get_object(Bucket=bucket, Key="{}/{}/resampled_stockdata.csv".format(s3_data_key, interval))
    loaded = pd.read_csv(io.BytesIO(obj['Body'].read()), parse_dates=True)
    mnemonics = list(loaded.Mnemonic.unique())
 
    return loaded, mnemonics

# %%
# %%time
interval = "H"
stockdata, stocksymbols = load_resampled_from_s3(interval, s3_bucket, s3_data_key)

# %%
stockdata.head()

# %% [markdown]
# ### Data exploration
# At the end, we do a quick check on the data, and plot some series to develop an intuition of what the data looks like.

# %%
matplotlib.rcParams['figure.figsize'] = (25, 17) # use bigger graphs
def timeseries_plot(mnemonics, metrics, data=None, interval = None, bucket = None, s3_key = None):
    if data is None and interval is not None and bucket is not None and s3_key is not None:
        data, symbols = load_resampled_from_s3(interval, bucket, s3_key)      
    columns = list(data.columns)
    ax = None
    for mnemonic in mnemonics:
        selected = data[data.Mnemonic == mnemonic].copy()
        selected.index = selected['CalcDateTime']
        selected = selected.sort_index()
        for column in columns:
            if column != 'CalcDateTime' and column != 'Mnemonic' and column not in metrics:
                selected = selected.drop(column, axis=1)
        selected_columns = list(selected.columns)
        for i, column in enumerate(selected_columns):
            selected_columns[i] = "{}-{}".format(mnemonic, column)
        selected.columns = selected_columns
        ax = selected.plot( ax = ax )

# %% [markdown]
# Let's plot ending price for 3 automobile companies - BMW, Daimler, Porsche, Volkwagen

# %%
timeseries_plot(['BMW', 'CON', 'DAI', 'PAH3', 'VOW3'], ['EndPrice'], stockdata)

# %% [markdown]
# Observe here since the four stocks we chose to display are all automobile companies, their movements show very similar pattern.
#
# We can also choose to display these stocks at lower resolution, such as at weekly interval, and still be able to observe the same patter.

# %%
timeseries_plot(['BMW', 'CON', 'DAI', 'PAH3', 'VOW3'], ['EndPrice'], interval = 'D', bucket = s3_bucket, s3_key = s3_data_key)

# %%
timeseries_plot(['BMW','CON', 'DAI', 'PAH3', 'VOW3'], ['EndPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# Now, in order to develop an intuition on how different time series for a single stock might influence each other,  we plot some metrices alongside each other, that might be somehow related, for a sample stock, in this case we just used "BMW".
#
#
# Since the data set gives minute by minute observation of values, it might clutter the visual plot when it comes to understanding the patterns in the data, use data resampled at higher interval rate, such as daily or weekly.<br>

# %%
timeseries_plot(['BMW'], ['EndPrice', 'MinPrice', 'MaxPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# ### Observation 1
#
# We can observed from the graph above:
#
# - When there is a downward trend, the `EndPrice` is closer to the `MinPrice`, than to the `MaxPrice`
# - When there is an upward trend, the `EndPrice` is closer to `MaxPrice` than to the `MinPrice`

# %%
timeseries_plot(['BMW'], ['StartPrice', 'MinPrice', 'MaxPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# ### Observation 2
# Similar (and correlated) behavior is true for the `StartPrice`:
#
# - When there is a downward trend, the `StartPrice` is closer to the `MaxPrice`, than to the `MinPrice`
# - When there is an upward trend, the `StartPrice` is closer to `MinPrice` than to the `MaxPrice`

# %%
timeseries_plot(['BMW'], ['StartPrice', 'EndPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# ### Observation 3
#
# Another observation that can be made is that:
# - when the trend is upwards, `EndPrice` is above `StartPrice`
# - when the trend is downwars, `EndPrice` is below `StartPrice`
#
# Therefore: if the lines of `EndPrice` and `StartPrice` cross, one could expect trend reversal.
# (Of course one needs to account for the variance, and false positives)

# %% [markdown]
# With these observations, we develop intuition that behaviour of the various metrices present in the data might have a correlation with future movement of the time series.<br>
#
#
# In the next step we apply Deep Neural Networks based Machine Learning techniques to try and find the correlation and hopefully be able to predict future movement, with certain confidence level.
