# %% [markdown]
# # Stock Price Prediction Using Deutsche Börse Dataset on SageMaker DeepAR
#
#
# ## Overview
# In this project we use Deutsche Börse Public Dataset consisting of trade data aggregated to one minute intervals from the Xetra trading systems
#
# We obtain the data from public S3 bucket, hosted by Deutsche Börse under AWS Open Data Registry, aggregate the data within a given period, and prepare training, test and validation sets.
# We then upload the prepared dat set to our own S3 bucket. This data location is then used with SageMaker provided DeepAR algorithm, to predict future movement of stock prices.
#
# Following diagrams provides an high level overview of the project architecture:
# ![ML Architecture](../images/architecture.png)

# %%
import os
import io
import datetime

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import autocorrelation_plot
from pandas.plotting import scatter_matrix
from jinja2 import Environment, FileSystemLoader

import boto3
import sagemaker

# %matplotlib inline

# Define IAM role and session
role = sagemaker.get_execution_role()
session = sagemaker.Session()

s3_data_key = 'dbg-stockdata/source'
s3_bucket = session.default_bucket()
processed_filename = 'dbg_processed'

source_bucket = "s3://deutsche-boerse-xetra-pds"

# %% [markdown]
# ## 1. Obtaining Data
#
# Since the DBG dataset is partitioned into separate folders by date, we generate a series of scripts to download the data files, in parallel.
#
# DBG dataset contains trading data beginning June-17, 2017. However we chose to download last 6 months of data, so that the processing time is manageable within the scope of this workshop session.

# %%
start_date = datetime.datetime.strptime('2017-07-01','%Y-%m-%d')
start_date_str = start_date.strftime('%Y-%m-%d')

end_date = datetime.datetime.strptime('2018-10-31','%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')


print(f"Download date range: {start_date_str} - {end_date_str}")
# Out:
# Download date range: 2017-07-01 - 2018-10-31

# %% [markdown]
# We store all files in a local folder, prior to pre-processing the data. <br>
# After processing, we store the processed data set in another folder, which we'll then upload to an our SageMaker S3 bucket.

# %%
download_folder = '../data/download'
processed_folder = '../data/processed'

! mkdir -p {download_folder}
! mkdir -p {processed_folder}

# %% [markdown]
# We then generate the download script in script folder and execute it to have the files downloaded.<br>
# Running bash script makes the download more reliable than running loops from Pythin runtime.

# %%
download_script = download_folder + '/download_files.sh'

dates = list(pd.date_range(start_date_str, end_date_str, freq='D').strftime('%Y-%m-%d'))

values_set = {
    "values_set": [
        {
            "date": date,
            "download_folder": download_folder,
            "source_bucket": source_bucket,
            "success_file": os.path.join(download_folder, date, "success")
        }
        for date in dates
    ]
}

env = Environment(loader=FileSystemLoader("."))

tpl = env.get_template("download_files.j2")

source_code = tpl.render(values_set)

with open(download_script, 'w') as f:
    f.write(source_code)

! chmod +x {download_script}

# %% [markdown]
# After creating the script, we run the script from shell, using Jupyter magic command.
#
# Downloading data should take about half an hour to an hour to complete depending on the dat range chosen.
#
# In order to avoid this process, you can alternative use the last cell in this notebook to obtain the prepared data from an S3 bucket accompanying this workshop, and load directly to your own S3 bucket.

# %%
# %%time
!  {download_script}
# Out:
# Getting DBG dataset for date 2017-07-01
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR00.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR02.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR05.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR09.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR03.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR04.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR06.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR07.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR01.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR14.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR13.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR10.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR17.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR12.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR15.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR16.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR19.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR11.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR23.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR20.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR18.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR21.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR22.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-01/2017-07-01_BINS_XETR08.csv to ../data/download/2017-07-01/2017-07-01_BINS_XETR08.csv
# Getting DBG dataset for date 2017-07-02
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR07.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR01.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR02.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR06.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR09.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR00.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR03.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR04.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR08.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR05.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR11.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR12.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR10.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR13.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR15.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR19.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR20.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR16.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR18.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR14.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR17.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR21.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR23.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-02/2017-07-02_BINS_XETR22.csv to ../data/download/2017-07-02/2017-07-02_BINS_XETR22.csv
# Getting DBG dataset for date 2017-07-03
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR01.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR02.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR04.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR00.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR05.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR16.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR17.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR18.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR19.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR21.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR23.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR03.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR06.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR22.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR07.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR08.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR09.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR20.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR15.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR14.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR10.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR11.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR12.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-03/2017-07-03_BINS_XETR13.csv to ../data/download/2017-07-03/2017-07-03_BINS_XETR13.csv
# Getting DBG dataset for date 2017-07-04
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR01.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR00.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR04.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR03.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR06.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR05.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR02.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR17.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR19.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR16.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR23.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR20.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR12.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR22.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR14.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR09.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR10.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR08.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR21.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR13.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR18.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR07.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR11.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-04/2017-07-04_BINS_XETR15.csv to ../data/download/2017-07-04/2017-07-04_BINS_XETR15.csv
# Getting DBG dataset for date 2017-07-05
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR01.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR04.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR03.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR05.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR02.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR00.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR06.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR16.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR20.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR18.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR17.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR21.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR19.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR07.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR22.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR08.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR23.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR11.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR13.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR12.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR10.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR14.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR15.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-05/2017-07-05_BINS_XETR09.csv to ../data/download/2017-07-05/2017-07-05_BINS_XETR09.csv
# Getting DBG dataset for date 2017-07-06
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR01.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR05.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR02.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR00.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR06.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR04.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR17.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR03.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR16.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR18.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR19.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR23.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR22.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR07.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR08.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR11.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR20.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR10.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR09.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR21.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR15.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR12.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR13.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-06/2017-07-06_BINS_XETR14.csv to ../data/download/2017-07-06/2017-07-06_BINS_XETR14.csv
# Getting DBG dataset for date 2017-07-07
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR03.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR00.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR04.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR01.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR02.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR06.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR05.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR20.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR18.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR17.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR10.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR08.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR07.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR19.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR11.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR12.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR16.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR13.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR09.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR21.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR22.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR23.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR15.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-07/2017-07-07_BINS_XETR14.csv to ../data/download/2017-07-07/2017-07-07_BINS_XETR14.csv
# Getting DBG dataset for date 2017-07-08
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR02.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR00.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR01.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR08.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR07.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR13.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR05.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR10.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR03.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR04.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR06.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR12.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR18.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR17.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR09.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR11.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR20.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR21.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR23.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR22.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR14.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR15.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR16.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-08/2017-07-08_BINS_XETR19.csv to ../data/download/2017-07-08/2017-07-08_BINS_XETR19.csv
# Getting DBG dataset for date 2017-07-09
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR00.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR08.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR02.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR09.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR03.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR04.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR01.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR05.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR07.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR06.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR12.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR17.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR10.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR11.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR14.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR19.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR20.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR16.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR21.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR15.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR13.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR23.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR18.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-09/2017-07-09_BINS_XETR22.csv to ../data/download/2017-07-09/2017-07-09_BINS_XETR22.csv
# Getting DBG dataset for date 2017-07-10
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR04.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR05.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR02.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR03.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR01.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR06.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR16.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR17.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR20.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR19.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR00.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR18.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR21.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR22.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR11.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR23.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR09.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR08.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR07.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR12.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR13.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR10.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR15.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-10/2017-07-10_BINS_XETR14.csv to ../data/download/2017-07-10/2017-07-10_BINS_XETR14.csv
# Getting DBG dataset for date 2017-07-11
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR01.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR04.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR00.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR05.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR06.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR03.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR02.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR16.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR17.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR22.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR21.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR08.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR07.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR09.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR23.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR10.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR11.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR20.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR18.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR19.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR13.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR12.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR15.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-11/2017-07-11_BINS_XETR14.csv to ../data/download/2017-07-11/2017-07-11_BINS_XETR14.csv
# Getting DBG dataset for date 2017-07-12
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR01.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR03.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR00.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR05.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR02.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR04.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR06.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR16.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR20.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR19.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR18.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR17.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR22.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR12.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR21.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR10.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR07.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR09.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR23.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR15.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR13.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR08.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR11.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-12/2017-07-12_BINS_XETR14.csv to ../data/download/2017-07-12/2017-07-12_BINS_XETR14.csv
# Getting DBG dataset for date 2017-07-13
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR00.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR02.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR06.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR04.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR01.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR05.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR03.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR17.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR19.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR18.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR23.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR12.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR10.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR09.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR08.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR16.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR07.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR21.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR11.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR22.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR20.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR13.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR14.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-13/2017-07-13_BINS_XETR15.csv to ../data/download/2017-07-13/2017-07-13_BINS_XETR15.csv
# Getting DBG dataset for date 2017-07-14
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR01.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR00.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR02.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR06.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR05.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR03.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR04.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR17.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR16.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR18.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR20.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR19.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR07.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR09.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR12.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR21.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR23.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR22.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR08.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR14.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR11.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR10.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR15.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-14/2017-07-14_BINS_XETR13.csv to ../data/download/2017-07-14/2017-07-14_BINS_XETR13.csv
# Getting DBG dataset for date 2017-07-15
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR06.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR03.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR01.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR04.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR05.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR02.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR08.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR07.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2017-07-15/2017-07-15_BINS_XETR00.csv to ../data/download/2017-07-15/2017-07-15_BINS_XETR00.csv
# ...
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR03.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR08.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR02.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR06.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR07.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR14.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR15.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR16.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR19.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR21.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR10.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR17.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR20.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR18.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR23.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR12.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR13.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR22.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-27/2018-10-27_BINS_XETR04.csv to ../data/download/2018-10-27/2018-10-27_BINS_XETR04.csv
# Getting DBG dataset for date 2018-10-28
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR00.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR02.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR01.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR04.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR03.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR13.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR06.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR07.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR08.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR05.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR14.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR12.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR09.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR16.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR11.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR18.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR17.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR10.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR19.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR21.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR22.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR15.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR23.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-28/2018-10-28_BINS_XETR20.csv to ../data/download/2018-10-28/2018-10-28_BINS_XETR20.csv
# Getting DBG dataset for date 2018-10-29
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR03.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR01.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR04.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR07.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR06.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR02.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR00.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR05.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR18.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR22.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR20.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR12.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR19.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR11.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR09.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR21.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR14.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR13.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR16.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR23.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR10.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR17.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR15.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-29/2018-10-29_BINS_XETR08.csv to ../data/download/2018-10-29/2018-10-29_BINS_XETR08.csv
# Getting DBG dataset for date 2018-10-30
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR04.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR02.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR05.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR07.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR00.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR03.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR06.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR01.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR20.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR19.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR17.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR09.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR10.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR12.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR21.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR18.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR23.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR11.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR13.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR13.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR08.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR22.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR16.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR14.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-30/2018-10-30_BINS_XETR15.csv to ../data/download/2018-10-30/2018-10-30_BINS_XETR15.csv
# Getting DBG dataset for date 2018-10-31
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR00.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR00.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR01.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR01.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR02.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR02.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR06.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR06.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR04.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR04.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR05.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR05.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR03.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR03.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR07.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR07.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR17.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR17.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR20.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR20.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR19.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR19.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR21.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR21.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR22.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR22.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR23.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR23.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR09.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR09.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR18.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR18.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR10.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR10.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR08.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR08.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR11.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR11.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR12.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR12.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR16.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR16.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR14.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR14.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR15.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR15.csv
# download: s3://deutsche-boerse-xetra-pds/2018-10-31/2018-10-31_BINS_XETR13.csv to ../data/download/2018-10-31/2018-10-31_BINS_XETR13.csv
# CPU times: user 1min 18s, sys: 32.8 s, total: 1min 51s
# Wall time: 42min 38s

# %% [markdown]
# ## 2. Data Preparation
#
# To prepare the data, we collect day wise tading data from separate files, filter out any data falling out of trading window, and not pertaining to common stock trading.
#
# ### 2.1. Load Data
# As first step we load all csv files in to a single data frame.
#
# Data loading should take about 1-2 hours to complete depending on the instance type you have chosen for your notebook instance.

# %%
# %%time
def convert_datetime(df):
    try: 
        df["CalcTime"] = pd.to_datetime("1900-01-01 " + df["Time"])
        df["CalcDateTime"] = pd.to_datetime(df["Date"] + " " + df["Time"])

    except:
        pass

    return df


def load_csvs(data_folder):
    df = None
    df_initialized = False
    data_dir = data_folder + '/'
    data_subdirs = list(map(lambda date: data_dir + date, dates))
    total_loaded = 0

    for data_subdir in data_subdirs:
        # data_subdir 配下の csv ファイルの Path を取得
        # ファイルサイズが 2000バイト以下のものは分析用のデータから除外
        # 残った Path を sort
        trading_files = sorted(
            list(
                filter(
                    lambda x:os.path.getsize(x)>2000,
                    [
                        os.path.join(data_subdir, x) 
                        for x in os.listdir(data_subdir) 
                        if x.endswith('.csv')
                    ]
                )
            )
        )

        if len(trading_files) > 0:
            print(f"Loading {len(trading_files)} files from {data_subdir}")

            if df_initialized == False:
                frame = [
                    pd.read_csv(f, engine='python', error_bad_lines=False, warn_bad_lines=False) 
                    for f in trading_files
                ]

                df = convert_datetime(pd.concat(frame, ignore_index = True))
                df_initialized = True

            else:
                dfa = convert_datetime(
                    pd.concat(
                        [
                            pd.read_csv(f, engine='python', error_bad_lines=False) 
                            for f in trading_files
                        ],
                        ignore_index = True
                    )
                )

                dft = [df, dfa]
                df = pd.concat(dft, ignore_index = True)

        total_loaded = total_loaded + len(trading_files)

        print(df.shape)

    print("Total of {} files loaded".format(total_loaded))

    return df

unprocessed_df = load_csvs(download_folder)
# Out:
# Loading 1 files from ../data/download/2017-07-01
# (2209, 16)
# (2209, 16)
# Loading 9 files from ../data/download/2017-07-03
# (62493, 16)
# Loading 9 files from ../data/download/2017-07-04
# (117825, 16)
# Loading 9 files from ../data/download/2017-07-05
# (181582, 16)
# Loading 9 files from ../data/download/2017-07-06
# (248227, 16)
# Loading 10 files from ../data/download/2017-07-07
# (309265, 16)
# (309265, 16)
# (309265, 16)
# Loading 9 files from ../data/download/2017-07-10
# (371743, 16)
# Loading 10 files from ../data/download/2017-07-11
# (433001, 16)
# Loading 10 files from ../data/download/2017-07-12
# (498140, 16)
# Loading 9 files from ../data/download/2017-07-13
# (562206, 16)
# Loading 10 files from ../data/download/2017-07-14
# (621008, 16)
# (621008, 16)
# (621008, 16)
# Loading 9 files from ../data/download/2017-07-17
# (683075, 16)
# Loading 9 files from ../data/download/2017-07-18
# (747833, 16)
# Loading 9 files from ../data/download/2017-07-19
# (808348, 16)
# Loading 9 files from ../data/download/2017-07-20
# (878431, 16)
# Loading 9 files from ../data/download/2017-07-21
# (946405, 16)
# (946405, 16)
# (946405, 16)
# Loading 9 files from ../data/download/2017-07-24
# (1013626, 16)
# Loading 9 files from ../data/download/2017-07-25
# (1080111, 16)
# Loading 9 files from ../data/download/2017-07-26
# (1145788, 16)
# Loading 9 files from ../data/download/2017-07-27
# (1211824, 16)
# Loading 10 files from ../data/download/2017-07-28
# (1277692, 16)
# (1277692, 16)
# (1277692, 16)
# Loading 10 files from ../data/download/2017-07-31
# (1342479, 16)
# Loading 9 files from ../data/download/2017-08-01
# (1409851, 16)
# Loading 9 files from ../data/download/2017-08-02
# (1476759, 16)
# Loading 9 files from ../data/download/2017-08-03
# (1543766, 16)
# Loading 9 files from ../data/download/2017-08-04
# (1608039, 16)
# (1608039, 16)
# (1608039, 16)
# Loading 9 files from ../data/download/2017-08-07
# (1670929, 16)
# Loading 9 files from ../data/download/2017-08-08
# (1735076, 16)
# Loading 10 files from ../data/download/2017-08-09
# (1806276, 16)
# Loading 9 files from ../data/download/2017-08-10
# (1876940, 16)
# Loading 9 files from ../data/download/2017-08-11
# (1953291, 16)
# (1953291, 16)
# (1953291, 16)
# Loading 9 files from ../data/download/2017-08-14
# (2017182, 16)
# Loading 10 files from ../data/download/2017-08-15
# (2078980, 16)
# Loading 9 files from ../data/download/2017-08-16
# (2140942, 16)
# Loading 9 files from ../data/download/2017-08-17
# (2204267, 16)
# Loading 6 files from ../data/download/2017-08-18
# (2242518, 16)
# (2242518, 16)
# (2242518, 16)
# Loading 9 files from ../data/download/2017-08-21
# (2302235, 16)
# Loading 9 files from ../data/download/2017-08-22
# (2360347, 16)
# Loading 9 files from ../data/download/2017-08-23
# (2421204, 16)
# Loading 9 files from ../data/download/2017-08-24
# (2480360, 16)
# Loading 10 files from ../data/download/2017-08-25
# (2538603, 16)
# (2538603, 16)
# (2538603, 16)
# Loading 9 files from ../data/download/2017-08-28
# (2589097, 16)
# Loading 9 files from ../data/download/2017-08-29
# (2661453, 16)
# Loading 9 files from ../data/download/2017-08-30
# (2720934, 16)
# Loading 9 files from ../data/download/2017-08-31
# (2785891, 16)
# Loading 9 files from ../data/download/2017-09-01
# (2853935, 16)
# (2853935, 16)
# (2853935, 16)
# Loading 9 files from ../data/download/2017-09-04
# (2909444, 16)
# Loading 9 files from ../data/download/2017-09-05
# (2971630, 16)
# Loading 9 files from ../data/download/2017-09-06
# (3035175, 16)
# Loading 9 files from ../data/download/2017-09-07
# (3100049, 16)
# Loading 10 files from ../data/download/2017-09-08
# (3161729, 16)
# (3161729, 16)
# (3161729, 16)
# Loading 9 files from ../data/download/2017-09-11
# (3226899, 16)
# Loading 9 files from ../data/download/2017-09-12
# (3292850, 16)
# Loading 10 files from ../data/download/2017-09-13
# (3356256, 16)
# Loading 10 files from ../data/download/2017-09-14
# (3419925, 16)
# Loading 9 files from ../data/download/2017-09-15
# (3484911, 16)
# (3484911, 16)
# (3484911, 16)
# Loading 9 files from ../data/download/2017-09-18
# (3546132, 16)
# Loading 9 files from ../data/download/2017-09-19
# (3605900, 16)
# Loading 9 files from ../data/download/2017-09-20
# (3664941, 16)
# Loading 9 files from ../data/download/2017-09-21
# (3727196, 16)
# Loading 9 files from ../data/download/2017-09-22
# (3787977, 16)
# (3787977, 16)
# (3787977, 16)
# Loading 9 files from ../data/download/2017-09-25
# (3848956, 16)
# Loading 9 files from ../data/download/2017-09-26
# (3913525, 16)
# Loading 10 files from ../data/download/2017-09-27
# (3976782, 16)
# Loading 9 files from ../data/download/2017-09-28
# (4039967, 16)
# Loading 9 files from ../data/download/2017-09-29
# (4104595, 16)
# (4104595, 16)
# (4104595, 16)
# Loading 9 files from ../data/download/2017-10-02
# (4174012, 16)
# (4174012, 16)
# Loading 9 files from ../data/download/2017-10-04
# (4247645, 16)
# Loading 9 files from ../data/download/2017-10-05
# (4312420, 16)
# Loading 9 files from ../data/download/2017-10-06
# (4375549, 16)
# (4375549, 16)
# (4375549, 16)
# Loading 10 files from ../data/download/2017-10-09
# (4437414, 16)
# Loading 9 files from ../data/download/2017-10-10
# (4499071, 16)
# Loading 9 files from ../data/download/2017-10-11
# (4559231, 16)
# Loading 9 files from ../data/download/2017-10-12
# (4620441, 16)
# Loading 10 files from ../data/download/2017-10-13
# (4682523, 16)
# (4682523, 16)
# (4682523, 16)
# Loading 9 files from ../data/download/2017-10-16
# (4746194, 16)
# Loading 9 files from ../data/download/2017-10-17
# (4809345, 16)
# Loading 9 files from ../data/download/2017-10-18
# (4871937, 16)
# Loading 9 files from ../data/download/2017-10-19
# (4941756, 16)
# Loading 9 files from ../data/download/2017-10-20
# (5006444, 16)
# (5006444, 16)
# (5006444, 16)
# (5006444, 16)
# (5006444, 16)
# Loading 9 files from ../data/download/2017-10-25
# (5072755, 16)
# Loading 10 files from ../data/download/2017-10-26
# (5140373, 16)
# Loading 6 files from ../data/download/2017-10-27
# (5187635, 16)
# (5187635, 16)
# (5187635, 16)
# (5187635, 16)
# (5187635, 16)
# Loading 9 files from ../data/download/2017-11-01
# (5265517, 16)
# Loading 9 files from ../data/download/2017-11-02
# (5341305, 16)
# Loading 9 files from ../data/download/2017-11-03
# (5412209, 16)
# (5412209, 16)
# (5412209, 16)
# Loading 9 files from ../data/download/2017-11-06
# (5479330, 16)
# Loading 9 files from ../data/download/2017-11-07
# (5549049, 16)
# Loading 9 files from ../data/download/2017-11-08
# (5619203, 16)
# Loading 9 files from ../data/download/2017-11-09
# (5695582, 16)
# Loading 9 files from ../data/download/2017-11-10
# (5766529, 16)
# (5766529, 16)
# (5766529, 16)
# Loading 9 files from ../data/download/2017-11-13
# (5839647, 16)
# Loading 9 files from ../data/download/2017-11-14
# (5910911, 16)
# Loading 10 files from ../data/download/2017-11-15
# (5987958, 16)
# Loading 9 files from ../data/download/2017-11-16
# (6057376, 16)
# Loading 9 files from ../data/download/2017-11-17
# (6124006, 16)
# (6124006, 16)
# (6124006, 16)
# Loading 9 files from ../data/download/2017-11-20
# (6191811, 16)
# Loading 9 files from ../data/download/2017-11-21
# (6261564, 16)
# Loading 9 files from ../data/download/2017-11-22
# (6328451, 16)
# Loading 9 files from ../data/download/2017-11-23
# (6390271, 16)
# Loading 9 files from ../data/download/2017-11-24
# (6455910, 16)
# (6455910, 16)
# (6455910, 16)
# Loading 9 files from ../data/download/2017-11-27
# (6522515, 16)
# Loading 9 files from ../data/download/2017-11-28
# (6589601, 16)
# Loading 9 files from ../data/download/2017-11-29
# (6659755, 16)
# Loading 9 files from ../data/download/2017-11-30
# (6732622, 16)
# Loading 9 files from ../data/download/2017-12-01
# (6808221, 16)
# (6808221, 16)
# (6808221, 16)
# Loading 9 files from ../data/download/2017-12-04
# (6880639, 16)
# Loading 9 files from ../data/download/2017-12-05
# (6951578, 16)
# Loading 9 files from ../data/download/2017-12-06
# (7021667, 16)
# Loading 9 files from ../data/download/2017-12-07
# (7088809, 16)
# Loading 10 files from ../data/download/2017-12-08
# (7157602, 16)
# (7157602, 16)
# (7157602, 16)
# Loading 9 files from ../data/download/2017-12-11
# (7221706, 16)
# Loading 10 files from ../data/download/2017-12-12
# (7287840, 16)
# Loading 10 files from ../data/download/2017-12-13
# (7354010, 16)
# Loading 9 files from ../data/download/2017-12-14
# (7424544, 16)
# Loading 9 files from ../data/download/2017-12-15
# (7494919, 16)
# (7494919, 16)
# (7494919, 16)
# Loading 9 files from ../data/download/2017-12-18
# (7569212, 16)
# Loading 9 files from ../data/download/2017-12-19
# (7638263, 16)
# Loading 10 files from ../data/download/2017-12-20
# (7708921, 16)
# Loading 9 files from ../data/download/2017-12-21
# (7775361, 16)
# Loading 9 files from ../data/download/2017-12-22
# (7836733, 16)
# (7836733, 16)
# (7836733, 16)
# (7836733, 16)
# (7836733, 16)
# Loading 10 files from ../data/download/2017-12-27
# (7898407, 16)
# Loading 9 files from ../data/download/2017-12-28
# (7957889, 16)
# Loading 6 files from ../data/download/2017-12-29
# (7996956, 16)
# (7996956, 16)
# (7996956, 16)
# (7996956, 16)
# Loading 9 files from ../data/download/2018-01-02
# (8065102, 16)
# Loading 9 files from ../data/download/2018-01-03
# (8135697, 16)
# Loading 9 files from ../data/download/2018-01-04
# (8204935, 16)
# Loading 9 files from ../data/download/2018-01-05
# (8272922, 16)
# (8272922, 16)
# (8272922, 16)
# Loading 9 files from ../data/download/2018-01-08
# (8343110, 16)
# Loading 9 files from ../data/download/2018-01-09
# (8409455, 16)
# Loading 10 files from ../data/download/2018-01-10
# (8478443, 16)
# Loading 9 files from ../data/download/2018-01-11
# (8546609, 16)
# Loading 9 files from ../data/download/2018-01-12
# (8612805, 16)
# (8612805, 16)
# (8612805, 16)
# Loading 9 files from ../data/download/2018-01-15
# (8675536, 16)
# Loading 9 files from ../data/download/2018-01-16
# (8743989, 16)
# Loading 9 files from ../data/download/2018-01-17
# (8809186, 16)
# Loading 9 files from ../data/download/2018-01-18
# (8874312, 16)
# Loading 9 files from ../data/download/2018-01-19
# (8942252, 16)
# (8942252, 16)
# (8942252, 16)
# Loading 9 files from ../data/download/2018-01-22
# (9007587, 16)
# Loading 9 files from ../data/download/2018-01-23
# (9076722, 16)
# Loading 9 files from ../data/download/2018-01-24
# (9143331, 16)
# Loading 9 files from ../data/download/2018-01-25
# (9213713, 16)
# Loading 9 files from ../data/download/2018-01-26
# (9277779, 16)
# (9277779, 16)
# (9277779, 16)
# Loading 9 files from ../data/download/2018-01-29
# (9342890, 16)
# Loading 10 files from ../data/download/2018-01-30
# (9412105, 16)
# Loading 10 files from ../data/download/2018-01-31
# (9479179, 16)
# Loading 9 files from ../data/download/2018-02-01
# (9555805, 16)
# Loading 9 files from ../data/download/2018-02-02
# (9631257, 16)
# (9631257, 16)
# (9631257, 16)
# Loading 9 files from ../data/download/2018-02-05
# (9714332, 16)
# Loading 9 files from ../data/download/2018-02-06
# (9819900, 16)
# Loading 9 files from ../data/download/2018-02-07
# (9902838, 16)
# Loading 9 files from ../data/download/2018-02-08
# (9979980, 16)
# Loading 9 files from ../data/download/2018-02-09
# (10068439, 16)
# (10068439, 16)
# (10068439, 16)
# Loading 9 files from ../data/download/2018-02-12
# (10143138, 16)
# Loading 9 files from ../data/download/2018-02-13
# (10209462, 16)
# Loading 10 files from ../data/download/2018-02-14
# (10279768, 16)
# Loading 9 files from ../data/download/2018-02-15
# (10352588, 16)
# Loading 9 files from ../data/download/2018-02-16
# (10418724, 16)
# (10418724, 16)
# (10418724, 16)
# Loading 9 files from ../data/download/2018-02-19
# (10477790, 16)
# Loading 9 files from ../data/download/2018-02-20
# (10539914, 16)
# Loading 9 files from ../data/download/2018-02-21
# (10602744, 16)
# Loading 9 files from ../data/download/2018-02-22
# (10666845, 16)
# Loading 9 files from ../data/download/2018-02-23
# (10727699, 16)
# (10727699, 16)
# (10727699, 16)
# Loading 9 files from ../data/download/2018-02-26
# (10790680, 16)
# Loading 9 files from ../data/download/2018-02-27
# (10856435, 16)
# Loading 9 files from ../data/download/2018-02-28
# (10920421, 16)
# Loading 9 files from ../data/download/2018-03-01
# (10995083, 16)
# Loading 9 files from ../data/download/2018-03-02
# (11076721, 16)
# (11076721, 16)
# (11076721, 16)
# Loading 9 files from ../data/download/2018-03-05
# (11147475, 16)
# Loading 9 files from ../data/download/2018-03-06
# (11216244, 16)
# Loading 9 files from ../data/download/2018-03-07
# (11284189, 16)
# Loading 9 files from ../data/download/2018-03-08
# (11351847, 16)
# Loading 9 files from ../data/download/2018-03-09
# (11416594, 16)
# (11416594, 16)
# (11416594, 16)
# Loading 9 files from ../data/download/2018-03-12
# (11482701, 16)
# Loading 9 files from ../data/download/2018-03-13
# (11550815, 16)
# Loading 10 files from ../data/download/2018-03-14
# (11617233, 16)
# Loading 9 files from ../data/download/2018-03-15
# (11683003, 16)
# Loading 9 files from ../data/download/2018-03-16
# (11746197, 16)
# (11746197, 16)
# (11746197, 16)
# Loading 9 files from ../data/download/2018-03-19
# (11813490, 16)
# Loading 9 files from ../data/download/2018-03-20
# (11879070, 16)
# Loading 10 files from ../data/download/2018-03-21
# (11943834, 16)
# Loading 9 files from ../data/download/2018-03-22
# (12018989, 16)
# Loading 9 files from ../data/download/2018-03-23
# (12101085, 16)
# (12101085, 16)
# (12101085, 16)
# Loading 9 files from ../data/download/2018-03-26
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed exec> in <module>()
#
# <timed exec> in load_csvs(data_folder)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     290
#     291             # consolidate
# --> 292             obj._consolidate(inplace=True)
#     293             ndims.add(obj.ndim)
#     294
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in _consolidate(self, inplace)
#    5154         inplace = validate_bool_kwarg(inplace, 'inplace')
#    5155         if inplace:
# -> 5156             self._consolidate_inplace()
#    5157         else:
#    5158             f = lambda: self._data.consolidate()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5136             self._data = self._data.consolidate()
#    5137
# -> 5138         self._protect_consolidate(f)
#    5139
#    5140     def _consolidate(self, inplace=False):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5125         """
#    5126         blocks_before = len(self._data.blocks)
# -> 5127         result = f()
#    5128         if len(self._data.blocks) != blocks_before:
#    5129             self._clear_item_cache()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/generic.py in f()
#    5134
#    5135         def f():
# -> 5136             self._data = self._data.consolidate()
#    5137
#    5138         self._protect_consolidate(f)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/managers.py in consolidate(self)
#     922         bm = self.__class__(self.blocks, self.axes)
#     923         bm._is_consolidated = False
# --> 924         bm._consolidate_inplace()
#     925         return bm
#     926
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     927     def _consolidate_inplace(self):
#     928         if not self.is_consolidated():
# --> 929             self.blocks = tuple(_consolidate(self.blocks))
#     930             self._is_consolidated = True
#     931             self._known_consolidated = True
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1897     for (_can_consolidate, dtype), group_blocks in grouper:
#    1898         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 1899                                       _can_consolidate=_can_consolidate)
#    1900         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    1901     return new_blocks
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3147
#    3148         argsort = np.argsort(new_mgr_locs)
# -> 3149         new_values = new_values[argsort]
#    3150         new_mgr_locs = new_mgr_locs[argsort]
#    3151
#
# MemoryError:

# %%
unprocessed_df.head()

# %% [markdown]
# ### 2.2. Filter records
# Next we filter the records pertaining to common stack with trading volumes greater than zero, and within the regular trading hours.
# Within the scope of this exercise, we focus our attention to top 100 stocks, by trading volume.
#
# This filtering should take about 1-2 minute to complete depending on the instance type you have chosen for your notebook instance.

# %%
# %%time
# Filter common stock between trading hours 08:00 and 20:00
# Exclude auctions (those are with TradeVolume == 0)
#Number of stocks to keep : Top 100, by trading volume
num_stocks=100
time_fmt = "%H:%M"
opening_hours_str = "08:00"
closing_hours_str = "20:00"
opening_hours = datetime.datetime.strptime(opening_hours_str, time_fmt)
closing_hours = datetime.datetime.strptime(closing_hours_str, time_fmt)

common_stocks = unprocessed_df[(unprocessed_df.SecurityType == 'Common stock') & \
                    (unprocessed_df.TradedVolume > 0) & \
                    (unprocessed_df.CalcTime >= opening_hours) & \
                    (unprocessed_df.CalcTime <= closing_hours)]

# Sort the stocks in descending order by trading volume
sort_by_volume = common_stocks[['Mnemonic', 'TradedVolume']].groupby(['Mnemonic']).sum().sort_values(['TradedVolume'], ascending=[0]).head(num_stocks)
stock_symbols = list(sort_by_volume.index.values)
sorted_stocks = common_stocks[common_stocks.Mnemonic.isin(stock_symbols)]
sorted_stocks = sorted_stocks.set_index(['Mnemonic', 'CalcDateTime']).sort_index()
stock_symbols = list(sort_by_volume.index.values)
print(sorted_stocks.shape)

# %% [markdown]
# Check to see how many days' records we imported. If you import all records starting from July-2017, to October-2018, it should contain 326 days' woth of records.

# %%
len(sorted(list(sorted_stocks['Date'].unique())))

# %% [markdown]
# ### 2.3. Select features by minute
#
# Next we build a clean data frame containing minute by minute transaction records with the following data points:
# - Mnemonic (Stock Ticker Symbol)
# - Minimum Price (During the interval)
# - Maximum Prixe (During the interval)
# - Start Price (At star of the interval)
# - End Price (At end of the interval)
# - Trading Volume (During the interval)
# - Number of Trades (During the interval)

# %%
# %%time
#Build minute by minute index for trading hours
non_empty_days = sorted(list(sorted_stocks['Date'].unique()))
def build_index(non_empty_days, from_time, to_time):
    date_ranges = []
    for date in non_empty_days:
        yyyy, mm, dd = date.split('-')
        from_hour, from_min = from_time.split(':')
        to_hour, to_min = to_time.split(':')    
        t1 = datetime.datetime(int(yyyy), int(mm), int(dd), int(from_hour),int(from_min),0)
        t2 = datetime.datetime(int(yyyy), int(mm), int(dd), int(to_hour),int(to_min),0) 
        date_ranges.append(pd.DataFrame({"OrganizedDateTime": pd.date_range(t1, t2, freq='1Min').values}))
    agg = pd.concat(date_ranges, axis=0) 
    agg.index = agg["OrganizedDateTime"]
    return agg

# Prepared data would contain numeric features for all stocks,
# for all days in the interval, for which there were trades (that means excluding weekends and holidays)
# for all minutes from 08:00 until 20:00
# in minutes without trades the prices from the last available minute are carried forward
# trades are filled with zero for such minutes

def basic_stock_features(input_df, mnemonic, time_index):
    stock = input_df.loc[mnemonic].copy()
    stock['HasTrade'] = 1.0    
    stock = stock.reindex(time_index)    
    features = ['MinPrice', 'MaxPrice', 'EndPrice', 'StartPrice']
    for f in features:
        stock[f] = stock[f].fillna(method='ffill')       
    features = ['HasTrade', 'TradedVolume', 'NumberOfTrades']
    for f in features:
        stock[f] = stock[f].fillna(0.0)    
    stock['Mnemonic'] = mnemonic
    selected_features = ['Mnemonic', 'MinPrice', 'MaxPrice', 'StartPrice', 'EndPrice', 'HasTrade', 'TradedVolume', 'NumberOfTrades']
    return stock[selected_features]

datetime_index = build_index(non_empty_days, opening_hours_str, closing_hours_str)["OrganizedDateTime"].values

stocks = []
for stock in stock_symbols:
    stock = basic_stock_features(sorted_stocks, stock, datetime_index)
    stocks.append(stock)

prepared = pd.concat(stocks, axis=0)
prepared.insert(0, 'Id', range(0, 0 + len(prepared)))
prepared = prepared.reset_index().set_index('Id')

# %%
prepared.head()

# %% [markdown]
# ### 2.4. Save processed data
# Finally we save the processed data and upload to our SageMaker S3 Bucket.<br>
# Source data, as downloaded from DBG dataset includes minute by minute details of price movement and trading numbers and volumes for the stocks. However, in practice, we might be interested in time series at various aggregation level, in order to do more effective hourly, daily or weekly predictions.
#
# Therefore we resample the data at various interval levels. First we define a resampling function that is able to resample various metrices for the aggregation levels.<br>
# For example, at a certain interval level, we are interested in:<br>
# - Last record for the End Price
# - First record for the Start Price
# - Minimum of all records for Min Price
# - Maximum of all records for Max Price
# - Total of all records for Number of Trades and Traded Volume

# %%
intervals = ['M', 'W', 'D', 'H']

def resample_data(df, interval = None, mnemonics=None, metrics=None):
    if mnemonics is None:
        mnemonics = list(df.Mnemonic.unique())
    if metrics is None:
        metrics = list(df.columns.values)
    if 'Mnemonic' in metrics:
        metrics.remove('Mnemonic')
    if 'HasTrade' in metrics:
        metrics.remove('HasTrade')        
        
    columns = list(df.columns.values)
    if 'CalcDateTime' not in columns:        
        df["CalcDateTime"] = pd.to_datetime(df["CalcDateTime"])
        
    if interval is None or not isinstance(interval, str) or interval not in intervals:
        raise ValueError('Interval not supported, must be one of : {}'.format(intervals))
        
    resampeled_frames = []         
    for mnemonic in mnemonics:
        print("Resampling {} records for interval - {}".format(mnemonic, interval))
        selected = df[df.Mnemonic == mnemonic].copy()
        selected.index = selected['CalcDateTime']
        selected = selected.sort_index()
        resampled = pd.DataFrame()   
        for metric in metrics:            
            if metric == 'EndPrice':
                resampled[metric] = selected[metric].resample(interval).last()
            elif metric == 'StartPrice':
                resampled[metric] = selected[metric].resample(interval).first()                   
            elif metric == 'MinPrice':
                resampled[metric] = selected[metric].resample(interval).min()                                 
            elif metric == 'MaxPrice':
                resampled[metric] = selected[metric].resample(interval).max()                                  
            elif metric == 'TradedVolume' or metric == "NumberOfTrades" :
                resampled[metric] = selected[metric].resample(interval).sum()                               
            else:
                pass
        resampled_columns = ['Mnemonic']
        for col in list(resampled.columns.values):
            resampled_columns.append(col)
        resampled['Mnemonic'] = mnemonic
        resampled = resampled[resampled_columns]  
        resampled.dropna(inplace = True)
        resampeled_frames.append(resampled)
    resampeleds = pd.concat(resampeled_frames)
    return resampeleds

# %% [markdown]
# Next we do a resampling for the following intervals and upload the file to an appropriate S3 location directly, saving local disk space:
# - Month
# - Week
# - Day
# - Hour
#
# Resampling of the time series data at four different interval levels should take about 10 to 20 minutes to complete, depending on the instance type you have chosen for your notebook instance.
#
# Note that this causes gaps in time series. However SageMaker DeepAR algorithm is designed to work with time series with gaps.

# %%
# %%time
for interval in intervals:
    rescaled_series = resample_data(prepared, interval)
    csv_buffer = io.StringIO()
    rescaled_series.to_csv(csv_buffer)
    s3_resource = boto3.resource('s3')
    s3_resource.Object(s3_bucket, '{}/{}/resampled_stockdata.csv'.format(s3_data_key, interval, interval)).put(Body=csv_buffer.getvalue())

# %% [markdown]
# Having the prepared data saved to an S3 bucket not only allows us to save some space in lcoal machine, but also helps when starting training job using SageMaker.<br>
# Since reading from S3 is optimized for high speed, when you are using an EC2 instance, which is what a SageMaker Notebook instance runs on, it makes sense to just load the data directly from S3, as and when needed.<br><br>
# Also, since SageMaker notebook instances come with only 5GB of Elastic Block Storage (to remain cost efficient), it is advisable to keep the device storage space clean, when not used.<br><br>
# Therefore, we delete the raw data files locally, to conserve storage space on notebook instance.

# %%
#Remove the download folder
# !rm -rf {download_folder}
#Reset the data frames loaded in memory
rescaled_series = None    
prepared = None
unprocessed_df = None

# %% [markdown]
# ### 2.5. Alternatively - Load resampled data for workshop
#
# Since obtaining raw data from source S3 buckets maintained by Deutsche Börse, filtering, resampling and uploading to SageMaker S3 bucket can take upward of two hours, within the time limit of this workshop you could obtain cleaned data as hosted directly from S3 buckets specifically maintained for this workshop.

# %%
import os
import io
import boto3
import sagemaker
import datetime
import pandas as pd
from pandas.tools.plotting import autocorrelation_plot
from pandas.tools.plotting import scatter_matrix
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Define IAM role and session
role = sagemaker.get_execution_role()
session = sagemaker.Session()

s3_data_key = 'dbg-stockdata/source'
s3_bucket = session.default_bucket()
processed_filename = 'dbg_processed'


workshop_bucket = "fsv-309"
intervals = ['M', 'W', 'D', 'H']
datafilename = "resampled_stockdata.csv "

for interval in intervals:
    # !aws s3 cp s3://{workshop_bucket}/{s3_data_key}/{interval}/{datafilename} s3://{s3_bucket}/{s3_data_key}/{interval}/{datafilename}

# %% [markdown]
# ### 2.6. Validate Data Load from S3
#
# Before moving on, we want to validate data by downloading from the location on S3 that we just saved, and run some quick introspection to develop an intuition about the nature of metrices and their possible influence on stock price movement.<br>
# For our preliminary analysis, we choose to load and investigate data with daily interval.

# %%
def load_resampled_from_s3(interval, bucket, s3_data_key):
    s3 = boto3.client('s3')
    obj = s3.get_object(Bucket=bucket, Key="{}/{}/resampled_stockdata.csv".format(s3_data_key, interval))
    loaded = pd.read_csv(io.BytesIO(obj['Body'].read()), parse_dates=True)
    mnemonics = list(loaded.Mnemonic.unique())
 
    return loaded, mnemonics

# %%
# %%time
interval = "H"
stockdata, stocksymbols = load_resampled_from_s3(interval, s3_bucket, s3_data_key)

# %%
stockdata.head()

# %% [markdown]
# ### Data exploration
# At the end, we do a quick check on the data, and plot some series to develop an intuition of what the data looks like.

# %%
matplotlib.rcParams['figure.figsize'] = (25, 17) # use bigger graphs
def timeseries_plot(mnemonics, metrics, data=None, interval = None, bucket = None, s3_key = None):
    if data is None and interval is not None and bucket is not None and s3_key is not None:
        data, symbols = load_resampled_from_s3(interval, bucket, s3_key)      
    columns = list(data.columns)
    ax = None
    for mnemonic in mnemonics:
        selected = data[data.Mnemonic == mnemonic].copy()
        selected.index = selected['CalcDateTime']
        selected = selected.sort_index()
        for column in columns:
            if column != 'CalcDateTime' and column != 'Mnemonic' and column not in metrics:
                selected = selected.drop(column, axis=1)
        selected_columns = list(selected.columns)
        for i, column in enumerate(selected_columns):
            selected_columns[i] = "{}-{}".format(mnemonic, column)
        selected.columns = selected_columns
        ax = selected.plot( ax = ax )

# %% [markdown]
# Let's plot ending price for 3 automobile companies - BMW, Daimler, Porsche, Volkwagen

# %%
timeseries_plot(['BMW', 'CON', 'DAI', 'PAH3', 'VOW3'], ['EndPrice'], stockdata)

# %% [markdown]
# Observe here since the four stocks we chose to display are all automobile companies, their movements show very similar pattern.
#
# We can also choose to display these stocks at lower resolution, such as at weekly interval, and still be able to observe the same patter.

# %%
timeseries_plot(['BMW', 'CON', 'DAI', 'PAH3', 'VOW3'], ['EndPrice'], interval = 'D', bucket = s3_bucket, s3_key = s3_data_key)

# %%
timeseries_plot(['BMW','CON', 'DAI', 'PAH3', 'VOW3'], ['EndPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# Now, in order to develop an intuition on how different time series for a single stock might influence each other,  we plot some metrices alongside each other, that might be somehow related, for a sample stock, in this case we just used "BMW".
#
#
# Since the data set gives minute by minute observation of values, it might clutter the visual plot when it comes to understanding the patterns in the data, use data resampled at higher interval rate, such as daily or weekly.<br>

# %%
timeseries_plot(['BMW'], ['EndPrice', 'MinPrice', 'MaxPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# ### Observation 1
#
# We can observed from the graph above:
#
# - When there is a downward trend, the `EndPrice` is closer to the `MinPrice`, than to the `MaxPrice`
# - When there is an upward trend, the `EndPrice` is closer to `MaxPrice` than to the `MinPrice`

# %%
timeseries_plot(['BMW'], ['StartPrice', 'MinPrice', 'MaxPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# ### Observation 2
# Similar (and correlated) behavior is true for the `StartPrice`:
#
# - When there is a downward trend, the `StartPrice` is closer to the `MaxPrice`, than to the `MinPrice`
# - When there is an upward trend, the `StartPrice` is closer to `MinPrice` than to the `MaxPrice`

# %%
timeseries_plot(['BMW'], ['StartPrice', 'EndPrice'], interval = 'W', bucket = s3_bucket, s3_key = s3_data_key)

# %% [markdown]
# ### Observation 3
#
# Another observation that can be made is that:
# - when the trend is upwards, `EndPrice` is above `StartPrice`
# - when the trend is downwars, `EndPrice` is below `StartPrice`
#
# Therefore: if the lines of `EndPrice` and `StartPrice` cross, one could expect trend reversal.
# (Of course one needs to account for the variance, and false positives)

# %% [markdown]
# With these observations, we develop intuition that behaviour of the various metrices present in the data might have a correlation with future movement of the time series.<br>
#
#
# In the next step we apply Deep Neural Networks based Machine Learning techniques to try and find the correlation and hopefully be able to predict future movement, with certain confidence level.
